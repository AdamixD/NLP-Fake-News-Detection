# %%
from training.model import Model
import pandas as pd

# %%
model = Model("nlptown/bert-base-multilingual-uncased-sentiment")
data_json = pd.read_json("data/preprocessed/covid", orient="records", lines=True)
tf_train, tf_test = model.prepare_train_test_data(data_json)
# Out:
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# All the layers of TFBertForSequenceClassification were initialized from the model checkpoint at nlptown/bert-base-multilingual-uncased-sentiment.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertForSequenceClassification for predictions without further training.
# c:\users\yaroslav\appdata\local\programs\python\python38\lib\site-packages\transformers\generation\tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...bert
# ......vars
# ...bert\embeddings
# ......vars
# .........0
# .........1
# .........2
# ...bert\embeddings\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\embeddings\dropout
# ......vars
# ...bert\encoder
# ......vars
# ...bert\encoder\layer\tf_bert_layer
# ......vars
# ...bert\encoder\layer\tf_bert_layer\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_10\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_10\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_10\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_10\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_10\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_10\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_10\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_11
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_11\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_11\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_11\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_11\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_11\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_11\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_11\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_1\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_1\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_1\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_1\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_1\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_1\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_1\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_1\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_2
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_2\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_2\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_2\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_2\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_2\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_2\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_2\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_3
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_3\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_3\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_3\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_3\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_3\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_3\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_3\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_4
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_4\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_4\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_4\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_4\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_4\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_4\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_4\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_5
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_5\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_5\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_5\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_5\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_5\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_5\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_5\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_6
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_6\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_6\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_6\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_6\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_6\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_6\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_6\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_7
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_7\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_7\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_7\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_7\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_7\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_7\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_7\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_8
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_8\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_8\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_8\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_8\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_8\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_8\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_8\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_9
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_9\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_9\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_9\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_9\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_9\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_9\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_9\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\pooler
# ......vars
# ...bert\pooler\dense
# ......vars
# .........0
# .........1
# ...classifier
# ......vars
# .........0
# .........1
# ...dropout
# ......vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-04-17 12:46:55         2406
# metadata.json                                  2023-04-17 12:46:55           64
# variables.h5                                   2023-04-17 12:46:56    669945008
# Map:   0%|          | 0/8160 [00:00<?, ? examples/s]
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...bert
# ......vars
# ...bert\embeddings
# ......vars
# .........0
# .........1
# .........2
# ...bert\embeddings\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\embeddings\dropout
# ......vars
# ...bert\encoder
# ......vars
# ...bert\encoder\layer\tf_bert_layer
# ......vars
# ...bert\encoder\layer\tf_bert_layer\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_10\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_10\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_10\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_10\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_10\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_10\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_10\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_11
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_11\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_11\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_11\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_11\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_11\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_11\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_11\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_1\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_1\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_1\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_1\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_1\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_1\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_1\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_1\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_2
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_2\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_2\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_2\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_2\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_2\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_2\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_2\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_3
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_3\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_3\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_3\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_3\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_3\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_3\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_3\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_4
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_4\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_4\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_4\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_4\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_4\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_4\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_4\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_5
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_5\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_5\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_5\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_5\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_5\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_5\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_5\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_6
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_6\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_6\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_6\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_6\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_6\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_6\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_6\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_7
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_7\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_7\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_7\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_7\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_7\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_7\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_7\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_8
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_8\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_8\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_8\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_8\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_8\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_8\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_8\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_9
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_9\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_9\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_9\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_9\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_9\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_9\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_9\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\pooler
# ......vars
# ...bert\pooler\dense
# ......vars
# .........0
# .........1
# ...classifier
# ......vars
# .........0
# .........1
# ...dropout
# ......vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-04-17 12:47:02         2406
# metadata.json                                  2023-04-17 12:47:02           64
# variables.h5                                   2023-04-17 12:47:03    669945008
# Map:   0%|          | 0/2041 [00:00<?, ? examples/s]

# %%
tf_train
# Out:
# <PrefetchDataset element_spec=({'input_ids': TensorSpec(shape=(16, None), dtype=tf.int64, name=None), 'token_type_ids': TensorSpec(shape=(16, None), dtype=tf.int64, name=None), 'attention_mask': TensorSpec(shape=(16, None), dtype=tf.int64, name=None)}, TensorSpec(shape=(16,), dtype=tf.int64, name=None))>

# %%
dataset = model.create_dataset(data_json)
tf_dataset = model.prepare_dataset(dataset)
tf_dataset
# Out:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...bert
# ......vars
# ...bert\embeddings
# ......vars
# .........0
# .........1
# .........2
# ...bert\embeddings\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\embeddings\dropout
# ......vars
# ...bert\encoder
# ......vars
# ...bert\encoder\layer\tf_bert_layer
# ......vars
# ...bert\encoder\layer\tf_bert_layer\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_10\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_10\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_10\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_10\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_10\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_10\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_10\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_10\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_11
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_11\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_11\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_11\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_11\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_11\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_11\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_11\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_11\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_1\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_1\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_1\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_1\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_1\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_1\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_1\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_1\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_1\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_2
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_2\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_2\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_2\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_2\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_2\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_2\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_2\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_2\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_3
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_3\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_3\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_3\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_3\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_3\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_3\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_3\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_3\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_4
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_4\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_4\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_4\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_4\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_4\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_4\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_4\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_4\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_5
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_5\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_5\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_5\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_5\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_5\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_5\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_5\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_5\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_6
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_6\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_6\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_6\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_6\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_6\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_6\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_6\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_6\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_7
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_7\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_7\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_7\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_7\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_7\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_7\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_7\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_7\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_8
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_8\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_8\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_8\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_8\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_8\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_8\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_8\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_8\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_9
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\attention\dense_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\attention\dense_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_9\attention\dense_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_9\attention\dense_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\attention\self_attention
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\attention\self_attention\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\attention\self_attention\key
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_9\attention\self_attention\query
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_9\attention\self_attention\value
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_9\bert_output
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\bert_output\LayerNorm
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_9\bert_output\dense
# ......vars
# .........0
# .........1
# ...bert\encoder\layer\tf_bert_layer_9\bert_output\dropout
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\intermediate
# ......vars
# ...bert\encoder\layer\tf_bert_layer_9\intermediate\dense
# ......vars
# .........0
# .........1
# ...bert\pooler
# ......vars
# ...bert\pooler\dense
# ......vars
# .........0
# .........1
# ...classifier
# ......vars
# .........0
# .........1
# ...dropout
# ......vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-04-17 12:47:07         2406
# metadata.json                                  2023-04-17 12:47:07           64
# variables.h5                                   2023-04-17 12:47:08    669945008
# Map:   0%|          | 0/10201 [00:00<?, ? examples/s]
# <PrefetchDataset element_spec=({'input_ids': TensorSpec(shape=(16, None), dtype=tf.int64, name=None), 'token_type_ids': TensorSpec(shape=(16, None), dtype=tf.int64, name=None), 'attention_mask': TensorSpec(shape=(16, None), dtype=tf.int64, name=None)}, TensorSpec(shape=(16,), dtype=tf.int64, name=None))>

# %%
model.compile()
history = model.fit(tf_train)
result = model.evaluate(tf_test)
# Out:
# No loss specified in compile() - the model's internal loss computation will be used as the loss. Don't panic - this is a common way to train TensorFlow models in Transformers! To disable this behaviour please pass a loss argument, or explicitly pass `loss=None` if you do not want your model to compute a loss.
# Epoch 1/3
# 510/510 [==============================] - 1330s 3s/step - loss: 0.1350
# Epoch 2/3
# 510/510 [==============================] - 1242s 2s/step - loss: 0.0798
# Epoch 3/3
# 510/510 [==============================] - 1249s 2s/step - loss: 0.0436
# 127/127 [==============================] - 57s 417ms/step - loss: 0.1389

# %%
result[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 result[0]
#
# TypeError: 'float' object is not subscriptable
